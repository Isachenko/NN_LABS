# %%
from math import exp
import math

almost_null = 0.0000001

def F_threshold_binary(s):
    return 0 if s <=0 else 1

def F_threshold_bipolar(s):
    return -1 if s<=0 else 1

def F_sigmoidal_binory(s, param = 1):
    return (1 / (1+(exp(-param * s) ) ) )
    
def F_sigmidal_bipolar(s, param = 1):
    return (2 / (1+(exp(-param * s)))) - 1;

def F_hiperbolic_tg(s):
    return F_sigmidal_bipolar(s, 2)

def F_linear(s):
    return s

def step_constant_small(_):
    return 0.01

def step_constant_medium(_):
    return 0.1

def step_constant_large(_):
    return 0.5

def step_adaptive(x):
    s = sum(xi**2 for xi in x)
    return 1.0 / (1 + s)

#import math
import matplotlib.pyplot as plt
from random import random, shuffle

# %%
def generate_dots(centerX1, centerX2, size, maxr, name):    
    points = []
    for i in range(size):
        r = random()*maxr
        alf = random()*(2*math.pi)
        x1 = centerX1 + r*math.sin(alf)
        x2 = centerX2 + r*math.cos(alf)
        points.append((x1, x2, name))
        
    return points

# %%
def count_weights(points, exitNeuronNum):
    shuffle(points)
    w1 = T = 0.9
    w2 = -0.9
    cur_epoch = 0
    good_epoch = False
    while(not good_epoch):
        good_epoch = True
        a = -w1/w2
        b = T/w2
        print "epoch: ", cur_epoch
        print "w1: ", w1
        print "w2: ", w2
        print "T: ", T
        plt.plot((-10, 10), (-10*a+b, 10*a+b),color='black')
        for cur_point in points:
            alf = step_adaptive(cur_point[0: 1])
            S = cur_point[0]*w1 + cur_point[1]*w2 - T
            y = F_sigmoidal_binory(S)
            print "y: ", y
            print cur_point
            name_e = (cur_point[2] >> exitNeuronNum) % 2
            print S, " ", y, " ", name_e
            K = y - name_e
            w1 = w1 - (alf * cur_point[0] * K)
            w2 = w2 - (alf * cur_point[1] * K)
            T = T + (alf * K)
            if abs(K) > 0.5 :
                good_epoch = False
        
        
        
        cur_epoch = cur_epoch + 1
        if (good_epoch):
            break
        if (cur_epoch > 10):
            break
    a = -w1/w2
    b = T/w2
    print (cur_epoch)
    return a, b

# %%
a = generate_dots(1, 1, 1, 0.1, 1)
b = generate_dots(1, -1, 1, 0.1, 0)
c = generate_dots(-1, 1, 1, 0.1, 0)
d = generate_dots(-1, -1, 1, 0.1, 0)
b.extend(c)
b.extend(d)


dots = []
dots.extend(a)
dots.extend(b)
#dots.extend(c)
#dots.extend(d)

l1, m1 = count_weights(dots, 0)
#l2, m2 = count_weights(dots, 1)


a = zip(*a)
b = zip(*b)
#c = zip(*c)
#d = zip(*d)


plt.plot(a[0], a[1], 'ro')
plt.plot(b[0], b[1], 'bo')
plt.plot((-10, 10), (-10*l1+m1, 10*l1+m1),color='red')
#plt.plot((-10, 10), (-10*l2+m2, 10*l2+m2),color='black')

plt.axis([-2, 2, -2, 2])

plt.show()
# Out:
# epoch:  0
# w1:  0.9
# w2:  -0.9
# T:  0.9
# y:  0.0600621186877
# (-0.979752904751295, 1.0762853744163594, 0)
# -2.75043445125   0.0600621186877   0
# y:  0.303444683959
# (1.0146208142044817, 0.9045449728904391, 1)
# -0.830947876626   0.303444683959   1
# y:  0.233872090057
# (-0.9654963735846896, -1.0200571430306817, 0)
# -1.18657479784   0.233872090057   0
# y:  0.762264976722
# (0.9875261499302969, -0.9936252887449913, 0)
# 1.16513752785   0.762264976722   0
# epoch:  1
# w1:  1.01402728197
# w2:  -0.115598332022
# T:  1.09437913181
# y:  0.098652072355
# (-0.979752904751295, 1.0762853744163594, 0)
# -2.21229210088   0.098652072355   0
# y:  0.445371104396
# (1.0146208142044817, 0.9045449728904391, 1)
# -0.219391356433   0.445371104396   1
# y:  0.0958007832108
# (-0.9654963735846896, -1.0200571430306817, 0)
# -2.24477884825   0.0958007832108   0
# y:  0.580051143601
# (0.9875261499302969, -0.9936252887449913, 0)
# 0.322983344889   0.580051143601   0
# epoch:  2
# w1:  1.09849639148
# w2:  0.419799588399
# T:  1.21467195617
# y:  0.137157433914
# (-0.979752904751295, 1.0762853744163594, 0)
# -1.8391028294   0.137157433914   0
# y:  0.552572052024
# (1.0146208142044817, 0.9045449728904391, 1)
# 0.211068321151   0.552572052024   1
# y:  0.0491835111967
# (-0.9654963735846896, -1.0200571430306817, 0)
# -2.96176264832   0.0491835111967   0
# y:  0.435805572672
# (0.9875261499302969, -0.9936252887449913, 0)
# -0.258202711747   0.435805572672   0
# 3
